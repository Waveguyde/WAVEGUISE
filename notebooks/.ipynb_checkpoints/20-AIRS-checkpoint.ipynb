# %%
# This is what I'm gonna need for the wavelet transform
import sys
sys.path.append("/home/r/Robert.Reichert/juwavelet")
import juwavelet.transform as transform
from juwavelet import utils

# This is for the data preprocessing and the segmentation
sys.path.append('../scripts')
import utils_2d_v3 as two
import plot_tools as pt

import xarray as xr
import numpy as np
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
import copy
import matplotlib.colors as mcolors
import time
from datetime import datetime, timedelta

plt.style.use("../latex_default_AMT.mplstyle")
# Out:
# /home/r/Robert.Reichert/.conda/envs/JuWavelet/lib/python3.12/site-packages/pyproj/network.py:59: UserWarning: pyproj unable to set PROJ database path.
#   _set_context_ca_bundle_path(ca_bundle_path)

# %%
data_path = '../data/pert_airs_l1_2022_015.nc'
ds = xr.open_dataset(data_path)

# %%
ds
# Out:
# <xarray.Dataset> Size: 187MB
# Dimensions:           (NTRACK: 32400, NXTRACK: 90)
# Dimensions without coordinates: NTRACK, NXTRACK
# Data variables: (12/13)
#     time              (NTRACK, NXTRACK) float64 23MB ...
#     lon               (NTRACK, NXTRACK) float64 23MB ...
#     lat               (NTRACK, NXTRACK) float64 23MB ...
#     bt_8mu            (NTRACK, NXTRACK) float32 12MB ...
#     bt_4mu            (NTRACK, NXTRACK) float32 12MB ...
#     bt_4mu_pt         (NTRACK, NXTRACK) float32 12MB ...
#     ...                ...
#     bt_15mu_low       (NTRACK, NXTRACK) float32 12MB ...
#     bt_15mu_low_pt    (NTRACK, NXTRACK) float32 12MB ...
#     bt_15mu_low_var   (NTRACK, NXTRACK) float32 12MB ...
#     bt_15mu_high      (NTRACK, NXTRACK) float32 12MB ...
#     bt_15mu_high_pt   (NTRACK, NXTRACK) float32 12MB ...
#     bt_15mu_high_var  (NTRACK, NXTRACK) float32 12MB ...

# %% [markdown]
# # First Antarctic Overpass

# %%
fig=plt.figure(figsize=(16,9))
ax=fig.add_subplot()
plot_T = ax.contourf(ds['bt_4mu_pt'].isel(NTRACK=slice(15_150,15_450)).T,levels=np.linspace(-0.5,0.5,21),cmap='RdBu_r',extend='both')
ax.set_aspect('equal')
plt.colorbar(plot_T,orientation='horizontal',fraction=0.05,label='Temperature / K')

# %%
track_slice = slice(15_150,15_450)
lon = ds["lon"].isel(NTRACK=track_slice)
lat = ds["lat"].isel(NTRACK=track_slice)

orig = ds["bt_4mu_pt"].isel(NTRACK=track_slice)
orig_copy = orig.copy()
BI_high, BI_low = two.BG_removal(orig_copy.values)
dx, dy = 20_000, 20_000
nx, ny = orig['NTRACK'].size, orig['NXTRACK'].size
y = np.linspace(0,(ny-1)*dy,ny)*1e-3
x = np.linspace(0,(nx-1)*dx,nx)*1e-3

nmask  = orig.shape
ntap   = int(0.1*np.min(nmask))
signal = utils.smooth_edges(BI_high, ntap, window='tukey')

print(f"Data size: {signal.shape[0]:.0f}x{signal.shape[1]:.0f}")
# Out:
# Data size: 300x90

# %%
s0 = 2 #smallest scale that we wanna resolve
s1 = 0.5 * min([nx,ny]) #largest scale we wanna resolve (since the first Fourier component is part of the background (BI_low) the largest scale fits twice in the domain)
dj = 1 / 8 # apäter wieder dj=1/8
js = int(1/dj*np.log2(s1/s0))
jt = 31

cwt_result = transform.decompose2d(signal,dx,dy,s0*min([dx,dy]),dj,js,jt,aspect=1,nxpad=None,nypad=None,opts={'param': 10},mode="scaled",dtype=np.complex128)

print(f"The data resolution is {dx*1e-3:.0f} km and the smallest wavelength you analyze is {cwt_result['period'][0]*1e-3:.0f} km.")
print(f"The data domain is at least {min([nx,ny])*dx*1e-3:.0f} km and the largest wavelength you analyze is {cwt_result['period'][-1]*1e-3:.0f} km.")

params = {
    "Smallest scale (s0)": f"{s0:.0f}",
    "Largest scale (s1)": f"{s1:.0f}",
    "Scale sampling (dj)": f"{dj:.3f}",
    "Number of scales (js)": f"{js:.0f}",
    "Number of azimuth angles (jt)": f"{jt:.0f}",
    "Non-dimensional frequency": f"{cwt_result['opts']['param']:.2f}",
}
label_width = max(len(label) for label in params)
for label, value in params.items():
    print(f"{label:<{label_width}} : {value}")
# Out:
# /home/r/Robert.Reichert/juwavelet/juwavelet/transform.py:324: RuntimeWarning: divide by zero encountered in divide
#   wys = periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :]))
# The data resolution is 20 km and the smallest wavelength you analyze is 25 km.
# The data domain is at least 1800 km and the largest wavelength you analyze is 478 km.
# Smallest scale (s0)           : 2
# Largest scale (s1)            : 45
# Scale sampling (dj)           : 0.125
# Number of scales (js)         : 35
# Number of azimuth angles (jt) : 31
# Non-dimensional frequency     : 10.00
# /home/r/Robert.Reichert/juwavelet/juwavelet/transform.py:367: RuntimeWarning: divide by zero encountered in divide
#   "wavelength_y": periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :])),

# %%
# Denoising
noise_level = 0.03 #units of BI
wavy_stuff, denoised_cwt = two.denoise_2d(cwt_result,white_noise_level=4*noise_level,sMAD_threshold=None,mean_axis=(1,2,3))

# %%
data_lev = np.linspace(-0.4,0.4,31)
fig = plt.figure(figsize=(16,6))
ax1 = fig.add_subplot(311)
plot_orig = ax1.contourf(x,y,orig.T,levels=data_lev,extend='both',cmap='RdBu_r')
cbar = fig.colorbar(plot_orig)

ax2 = fig.add_subplot(312)
plot_dirt = ax2.contourf(x,y,BI_low.T+signal.T-wavy_stuff.T+np.mean(orig.values),levels=data_lev,extend='both',cmap='RdBu_r')
cbar = fig.colorbar(plot_dirt)

ax3 = fig.add_subplot(313)
plot_wave = ax3.contourf(x,y,wavy_stuff.T,levels=data_lev,extend='both',cmap='RdBu_r')
cbar = fig.colorbar(plot_wave)

ax3.set_xlabel('Along Distance / km')
ax1.set_ylabel('Across Distance / km')
ax2.set_ylabel('Across Distance / km')
ax3.set_ylabel('Across Distance / km')

letterbox = {"boxstyle": "circle","lw": 0.67,"facecolor": "white","edgecolor": "black"}
ax1.text(0.03,0.94,'a',transform=ax1.transAxes, bbox=letterbox, verticalalignment="top", horizontalalignment="right", weight="bold") 
ax2.text(0.03,0.94,'b',transform=ax2.transAxes, bbox=letterbox, verticalalignment="top", horizontalalignment="right", weight="bold") 
ax3.text(0.03,0.94,'c',transform=ax3.transAxes, bbox=letterbox, verticalalignment="top", horizontalalignment="right", weight="bold") 

plt.savefig('./figures/2D_example_AIRS_OP_1_filter.png',dpi=150,bbox_inches="tight",pad_inches=0.02)

# %%
# Falls xarray DataArrays: in numpy arrays umwandeln
lon_plot = lon.values
lat_plot = lat.values

central_lon = -175
central_lat = -78.0

proj = ccrs.NearsidePerspective(central_longitude=central_lon, central_latitude=central_lat, satellite_height=35785831, false_easting=0, false_northing=0, globe=None)
data_crs = ccrs.PlateCarree()

row, col = 1, 3

gskw = {"hspace": 0.05, "wspace": 0.05, "width_ratios": [10, 10, 1], "height_ratios": [1] * row}

fig, ax = plt.subplots(row, col, figsize=(12, 9), subplot_kw={"projection": proj}, gridspec_kw=gskw, squeeze=False)
ax[0,2].axis('off')

plot_signal = ax[0, 0].scatter(lon_plot, lat_plot, c=signal, s=1, vmin=-0.4, vmax=0.4, cmap='RdBu_r', transform=data_crs)
plot_bg     = ax[0, 1].scatter(lon_plot, lat_plot, c=signal-wavy_stuff, s=1, vmin=-0.4, vmax=0.4, cmap='RdBu_r', transform=data_crs)

ax[0,0].plot([-175,-175],[-20,-90],transform=data_crs, linewidth=2)

seconds = ds.time.isel(NTRACK=track_slice).mean().values
date = datetime(2000, 1, 1) + timedelta(seconds=int(seconds))

ax[0,0].set_title(date)

for i in range(1):
    for j in range(2):
        ax[i, j].coastlines(linewidth=0.5)
        gl = ax[i, j].gridlines(draw_labels=False, linewidth=0.4, color="gray", alpha=0.5, linestyle="--")
        
        ax[i, j].set_extent(
            [
                np.nanmin(lon_plot),
                np.nanmax(lon_plot),
                np.nanmin(lat_plot),
                np.nanmax(lat_plot),
            ],
            crs=data_crs
        )
        
        
fig.colorbar(plot_signal, ax=ax[0,2], orientation="vertical", label="Temperature perturbation / K")

letterbox = {"boxstyle": "circle","lw": 0.67,"facecolor": "white","edgecolor": "black"}
ax[0,0].text(0.05,0.95,'a',transform=ax[0,0].transAxes, bbox=letterbox, verticalalignment="top", horizontalalignment="right", weight="bold") 
ax[0,1].text(0.05,0.95,'b',transform=ax[0,1].transAxes, bbox=letterbox, verticalalignment="top", horizontalalignment="right", weight="bold") 

plt.savefig('./figures/2D_example_AIRS_OP1.png',dpi=150,bbox_inches="tight",pad_inches=0.02)

# %%
WAS        = np.abs(denoised_cwt['decomposition'])
start_time = time.time()
seg_v1     = two.wavefield_segmentation_2d(WAS,0.1*noise_level,connectivity=1)
print("--- %s seconds ---" % (time.time() - start_time))
print('Identified', np.max(seg_v1), 'initial wave packets!')

k     = 2 * np.pi / cwt_result["period"]
theta = cwt_result["theta"]
eps   = np.abs(np.diff(np.log(k)))[0]*np.sqrt(2)
labels, cluster_labels = two.find_clusters_logk_theta(denoised_cwt, seg_v1, eps=eps)
cluster_map            = two.build_cluster_map_with_noise(labels,cluster_labels)
seg_v2                 = two.relabel_by_xy_overlap(seg_v1, cluster_map)
print('Number of wave packets after Clustering', np.max(seg_v2))
# Out:
# --- 117.32208037376404 seconds ---
# Identified 473 initial wave packets!
# suggested scaling: 0.8549629505915273
# Number of wave packets after Clustering 41

# %%
seg_v3 = two.variance_filter(denoised_cwt, seg_v2, var_threshold=0.99)
print('Final number of wave packets:', np.max(seg_v3))
# Out:
# Final number of wave packets: 6

# %%
recon_WP, amp_WP, k_along_WP, k_across_WP = two.recon_allWP_2d(denoised_cwt, seg_v3)
lh_WP, th_WP = two.kxky_2_lhtheta(k_along_WP,k_across_WP)
# Out:
# 100%|██████████| 27000/27000 [00:01<00:00, 24980.40it/s]
# 100%|██████████| 27000/27000 [00:00<00:00, 42441.78it/s]
# 100%|██████████| 27000/27000 [00:00<00:00, 56975.27it/s]
# 100%|██████████| 27000/27000 [00:00<00:00, 34388.98it/s]
# 100%|██████████| 27000/27000 [00:00<00:00, 46866.43it/s]
# 100%|██████████| 27000/27000 [00:00<00:00, 27218.90it/s]
# /home/r/Robert.Reichert/WAVEGUISE/notebooks/../scripts/utils_2d_v3.py:949: RuntimeWarning: divide by zero encountered in divide
#   return 2*np.pi/k, theta

# %%
data_lev = np.linspace(-0.4,0.4,31)
row, col = pt.define_figgrid(recon_WP.shape[0])
gskw = {"hspace": 0.05, "wspace": 0.05, "width_ratios": col*[1], "height_ratios": row*[1]}

fig, ax=plt.subplots(row,col, figsize=(36,12), gridspec_kw=gskw,sharex=True, sharey=True)

for i in range(row):
    for j in range(col):
        if i*col+j < recon_WP.shape[0]:
            #ax[i][j].contourf(the_new_shit[i*col+j,:,:],levels=rad_lev,extend="both",cmap="RdBu_r")
            masked = np.ma.masked_inside(recon_WP[i*col+j,:,:], -noise_level*0.1, noise_level*0.1)  
            norm = mcolors.TwoSlopeNorm(vmin=data_lev[0], vcenter=0.0, vmax=data_lev[-1])
            ax[i,j].contourf(x,y,masked.T,levels=data_lev,cmap="RdBu_r",norm=norm,extend='both')
            ax[i,j].text(0.5, 0.95, str(i*col+j+1), verticalalignment='center', horizontalalignment='center', transform=ax[i,j].transAxes, 
                                    weight='bold', bbox={"boxstyle" : "round", "lw":0.67, "facecolor":"white", "edgecolor":"black"})

# %% [markdown]
# # Second Antarctic Overpass

# %%
fig=plt.figure(figsize=(16,9))
ax=fig.add_subplot()
plot_T = ax.contourf(ds['bt_4mu_pt'].isel(NTRACK=slice(17_480,17_650)).T,levels=np.linspace(-0.5,0.5,21),cmap='RdBu_r',extend='both')
ax.set_aspect('equal')
plt.colorbar(plot_T,orientation='horizontal',fraction=0.05,label='Temperature / K')

# %%
track_slice = slice(17_480,17_650)
lon = ds["lon"].isel(NTRACK=track_slice)
lat = ds["lat"].isel(NTRACK=track_slice)

orig = ds["bt_4mu_pt"].isel(NTRACK=track_slice)
orig_copy = orig.copy()
BI_high, BI_low = two.BG_removal(orig_copy.values)
dx, dy = 20_000, 20_000
nx, ny = orig['NTRACK'].size, orig['NXTRACK'].size
y = np.linspace(0,(ny-1)*dy,ny)*1e-3
x = np.linspace(0,(nx-1)*dx,nx)*1e-3

nmask  = orig.shape
ntap   = int(0.1*np.min(nmask))
signal = utils.smooth_edges(BI_high, ntap, window='tukey')

print(f"Data size: {signal.shape[0]:.0f}x{signal.shape[1]:.0f}")
# Out:
# Data size: 170x90

# %%
s0 = 2 #smallest scale that we wanna resolve
s1 = 0.5 * min([nx,ny]) #largest scale we wanna resolve (since the first Fourier component is part of the background (BI_low) the largest scale fits twice in the domain)
dj = 1 / 8 # apäter wieder dj=1/8
js = int(1/dj*np.log2(s1/s0))
jt = 31

cwt_result = transform.decompose2d(signal,dx,dy,s0*min([dx,dy]),dj,js,jt,aspect=1,nxpad=None,nypad=None,opts={'param': 10},mode="scaled",dtype=np.complex128)

print(f"The data resolution is {dx*1e-3:.0f} km and the smallest wavelength you analyze is {cwt_result['period'][0]*1e-3:.0f} km.")
print(f"The data domain is at least {min([nx,ny])*dx*1e-3:.0f} km and the largest wavelength you analyze is {cwt_result['period'][-1]*1e-3:.0f} km.")

params = {
    "Smallest scale (s0)": f"{s0:.0f}",
    "Largest scale (s1)": f"{s1:.0f}",
    "Scale sampling (dj)": f"{dj:.3f}",
    "Number of scales (js)": f"{js:.0f}",
    "Number of azimuth angles (jt)": f"{jt:.0f}",
    "Non-dimensional frequency": f"{cwt_result['opts']['param']:.2f}",
}
label_width = max(len(label) for label in params)
for label, value in params.items():
    print(f"{label:<{label_width}} : {value}")
# Out:
# /home/r/Robert.Reichert/juwavelet/juwavelet/transform.py:324: RuntimeWarning: divide by zero encountered in divide
#   wys = periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :]))
# The data resolution is 20 km and the smallest wavelength you analyze is 25 km.
# The data domain is at least 1800 km and the largest wavelength you analyze is 478 km.
# Smallest scale (s0)           : 2
# Largest scale (s1)            : 45
# Scale sampling (dj)           : 0.125
# Number of scales (js)         : 35
# Number of azimuth angles (jt) : 31
# Non-dimensional frequency     : 10.00
# /home/r/Robert.Reichert/juwavelet/juwavelet/transform.py:367: RuntimeWarning: divide by zero encountered in divide
#   "wavelength_y": periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :])),

# %%
# Denoising
noise_level = 0.03 #units of BI
wavy_stuff, denoised_cwt = two.denoise_2d(cwt_result,white_noise_level=4*noise_level,sMAD_threshold=None,mean_axis=(1,2,3))

# %%
data_lev = np.linspace(-0.4,0.4,31)
fig = plt.figure(figsize=(16,9))
ax1 = fig.add_subplot(311)
plot_orig = ax1.contourf(x,y,orig.T,levels=data_lev,extend='both',cmap='RdBu_r')
cbar = fig.colorbar(plot_orig)

ax2 = fig.add_subplot(312)
plot_dirt = ax2.contourf(x,y,BI_low.T+signal.T-wavy_stuff.T+np.mean(orig.values),levels=data_lev,extend='both',cmap='RdBu_r')
cbar = fig.colorbar(plot_dirt)

ax3 = fig.add_subplot(313)
plot_wave = ax3.contourf(x,y,wavy_stuff.T,levels=data_lev,extend='both',cmap='RdBu_r')
cbar = fig.colorbar(plot_wave)

ax3.set_xlabel('Along Distance / km')
ax1.set_ylabel('Across Distance / km')
ax2.set_ylabel('Across Distance / km')
ax3.set_ylabel('Across Distance / km')

letterbox = {"boxstyle": "circle","lw": 0.67,"facecolor": "white","edgecolor": "black"}
ax1.text(0.03,0.94,'a',transform=ax1.transAxes, bbox=letterbox, verticalalignment="top", horizontalalignment="right", weight="bold") 
ax2.text(0.03,0.94,'b',transform=ax2.transAxes, bbox=letterbox, verticalalignment="top", horizontalalignment="right", weight="bold") 
ax3.text(0.03,0.94,'c',transform=ax3.transAxes, bbox=letterbox, verticalalignment="top", horizontalalignment="right", weight="bold")
# Out:
# Text(0.03, 0.94, 'c')

# %%
WAS        = np.abs(denoised_cwt['decomposition'])
start_time = time.time()
seg_v1     = two.wavefield_segmentation_2d(WAS,0.1*noise_level,connectivity=1)
print("--- %s seconds ---" % (time.time() - start_time))
print('Identified', np.max(seg_v1), 'initial wave packets!')

k     = 2 * np.pi / cwt_result["period"]
theta = cwt_result["theta"]
eps   = np.abs(np.diff(np.log(k)))[0]*np.sqrt(2)
labels, cluster_labels = two.find_clusters_logk_theta(denoised_cwt, seg_v1, eps=eps)
cluster_map            = two.build_cluster_map_with_noise(labels,cluster_labels)
seg_v2                 = two.relabel_by_xy_overlap(seg_v1, cluster_map)
print('Number of wave packets after Clustering', np.max(seg_v2))
# Out:
# --- 72.35029244422913 seconds ---
# Identified 290 initial wave packets!
# suggested scaling: 0.8549629505915273
# Number of wave packets after Clustering 45

# %%
seg_v3 = two.variance_filter(denoised_cwt, seg_v2, var_threshold=0.99)
print('Final number of wave packets:', np.max(seg_v3))
# Out:
# Final number of wave packets: 4

# %%
recon_WP, amp_WP, k_along_WP, k_across_WP = two.recon_allWP_2d(denoised_cwt, seg_v3)
lh_WP, th_WP = two.kxky_2_lhtheta(k_along_WP,k_across_WP)
# Out:
# 100%|██████████| 15300/15300 [00:00<00:00, 36667.67it/s]
# 100%|██████████| 15300/15300 [00:00<00:00, 37608.63it/s]
# 100%|██████████| 15300/15300 [00:00<00:00, 40995.17it/s]
# 100%|██████████| 15300/15300 [00:00<00:00, 61096.81it/s]
# /home/r/Robert.Reichert/WAVEGUISE/notebooks/../scripts/utils_2d_v3.py:949: RuntimeWarning: divide by zero encountered in divide
#   return 2*np.pi/k, theta

# %%
plt.rcParams.update({
    "font.size": 16,
    "axes.labelsize": 18,
    "axes.titlesize": 20,
    "xtick.labelsize": 14,
    "ytick.labelsize": 14,
    "legend.fontsize": 14,
})

# Falls xarray DataArrays: in numpy arrays umwandeln
lon_plot = lon.values
lat_plot = lat.values

central_lon = -175
central_lat = -78.0
proj = ccrs.NearsidePerspective(central_longitude=central_lon, central_latitude=central_lat, satellite_height=35785831, false_easting=0, false_northing=0, globe=None)
data_crs = ccrs.PlateCarree()

row, col = 2, 3

gskw = {"hspace": 0.01, "wspace": 0.05, "width_ratios": [1, 1, 1], "height_ratios": [10,1]}

fig, ax = plt.subplots(row, col, figsize=(13.333, 7.5), subplot_kw={"projection": proj}, gridspec_kw=gskw, squeeze=False)
ax[1,0].axis('off')
ax[1,1].axis('off')
ax[1,2].axis('off')

plot_orig = ax[0, 0].scatter(lon_plot, lat_plot, c=signal, s=1, vmin=-0.2, vmax=0.2, cmap='RdBu_r', transform=data_crs)

amp_mask = amp_WP[0,:,:] > noise_level/2 
plot_WP_0 = ax[0, 1].scatter(lon_plot[amp_mask], lat_plot[amp_mask], c=recon_WP[0,:,:][amp_mask], s=1, vmin=-0.2, vmax=0.2, cmap='RdBu_r', transform=data_crs)
pt.plot_k_vector(lon_plot,lat_plot,-k_across_WP[0],-k_along_WP[0],25,ax[0,1],proj,scale=0.02,mask=amp_mask)

amp_mask = amp_WP[1,:,:] > noise_level/2 
plot_WP_1 = ax[0, 2].scatter(lon_plot[amp_mask], lat_plot[amp_mask], c=recon_WP[1,:,:][amp_mask], s=1, vmin=-0.2, vmax=0.2, cmap='RdBu_r', transform=data_crs)
pt.plot_k_vector(lon_plot,lat_plot,-k_across_WP[1],-k_along_WP[1],25,ax[0,2],proj,scale=0.02,mask=amp_mask)

seconds = ds.time.isel(NTRACK=track_slice).mean().values
date = datetime(2000, 1, 1) + timedelta(seconds=int(seconds))

ax[0,1].set_title(date)

for i in range(1):
    for j in range(3):
        ax[i, j].coastlines(linewidth=0.5)
        gl = ax[i, j].gridlines(draw_labels=False, linewidth=0.4, color="gray", alpha=0.5, linestyle="--")

        ax[i, j].set_extent(
            [
                np.nanmin(lon_plot),
                np.nanmax(lon_plot),
                np.nanmin(lat_plot),
                np.nanmax(lat_plot),
            ],
            crs=data_crs
        )
        
fig.colorbar(plot_WP_0, ax=ax[1,:], orientation="horizontal", label="Temperature perturbation / K", fraction=0.67, pad=0)

#letterbox = {"boxstyle": "circle","lw": 0.67,"facecolor": "white","edgecolor": "black"}
titlebox = {"boxstyle": "round", "lw": 0.33, "facecolor": "white", "edgecolor": "black", "alpha": 0.67}
ax[0,0].text(0.95,0.95,'original',transform=ax[0,0].transAxes, bbox=titlebox, verticalalignment="top", horizontalalignment="right", weight="bold") 
ax[0,1].text(0.95,0.95,'dominant wave',transform=ax[0,1].transAxes, bbox=titlebox, verticalalignment="top", horizontalalignment="right", weight="bold") 
ax[0,2].text(0.95,0.95,'sub-dominant wave',transform=ax[0,2].transAxes, bbox=titlebox, verticalalignment="top", horizontalalignment="right", weight="bold") 

#plt.savefig('./figures/2D_example_AIRS_OP2_v2.png',dpi=150,bbox_inches="tight",pad_inches=0.05)
# Out:
# Text(0.95, 0.95, 'sub-dominant wave')

# %% [markdown]
# # Third Antarctic Overpass

# %%
fig=plt.figure(figsize=(16,9))
ax=fig.add_subplot()
plot_T = ax.contourf(ds['bt_4mu_pt'].isel(NTRACK=slice(19_750,19_950)).T,levels=np.linspace(-0.5,0.5,21),cmap='RdBu_r',extend='both')
ax.set_aspect('equal')
plt.colorbar(plot_T,orientation='horizontal',fraction=0.05,label='Temperature / K')

# %%
track_slice = slice(19_750,19_950)
lon = ds["lon"].isel(NTRACK=track_slice)
lat = ds["lat"].isel(NTRACK=track_slice)

orig = ds["bt_4mu_pt"].isel(NTRACK=track_slice)
orig_copy = orig.copy()
BI_high, BI_low = two.BG_removal(orig_copy.values)
dx, dy = 20_000, 20_000
nx, ny = orig['NTRACK'].size, orig['NXTRACK'].size
y = np.linspace(0,(ny-1)*dy,ny)*1e-3
x = np.linspace(0,(nx-1)*dx,nx)*1e-3

nmask  = orig.shape
ntap   = int(0.1*np.min(nmask))
signal = utils.smooth_edges(BI_high, ntap, window='tukey')

print(f"Data size: {signal.shape[0]:.0f}x{signal.shape[1]:.0f}")
# Out:
# Data size: 200x90

# %%
s0 = 2 #smallest scale that we wanna resolve
s1 = 0.5 * min([nx,ny]) #largest scale we wanna resolve (since the first Fourier component is part of the background (BI_low) the largest scale fits twice in the domain)
dj = 1 / 8 # apäter wieder dj=1/8
js = int(1/dj*np.log2(s1/s0))
jt = 31

cwt_result = transform.decompose2d(signal,dx,dy,s0*min([dx,dy]),dj,js,jt,aspect=1,nxpad=None,nypad=None,opts={'param': 10},mode="scaled",dtype=np.complex128)

print(f"The data resolution is {dx*1e-3:.0f} km and the smallest wavelength you analyze is {cwt_result['period'][0]*1e-3:.0f} km.")
print(f"The data domain is at least {min([nx,ny])*dx*1e-3:.0f} km and the largest wavelength you analyze is {cwt_result['period'][-1]*1e-3:.0f} km.")

params = {
    "Smallest scale (s0)": f"{s0:.0f}",
    "Largest scale (s1)": f"{s1:.0f}",
    "Scale sampling (dj)": f"{dj:.3f}",
    "Number of scales (js)": f"{js:.0f}",
    "Number of azimuth angles (jt)": f"{jt:.0f}",
    "Non-dimensional frequency": f"{cwt_result['opts']['param']:.2f}",
}
label_width = max(len(label) for label in params)
for label, value in params.items():
    print(f"{label:<{label_width}} : {value}")
# Out:
# /home/r/Robert.Reichert/juwavelet/juwavelet/transform.py:324: RuntimeWarning: divide by zero encountered in divide
#   wys = periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :]))
# The data resolution is 20 km and the smallest wavelength you analyze is 25 km.
# The data domain is at least 1800 km and the largest wavelength you analyze is 478 km.
# Smallest scale (s0)           : 2
# Largest scale (s1)            : 45
# Scale sampling (dj)           : 0.125
# Number of scales (js)         : 35
# Number of azimuth angles (jt) : 31
# Non-dimensional frequency     : 10.00
# /home/r/Robert.Reichert/juwavelet/juwavelet/transform.py:367: RuntimeWarning: divide by zero encountered in divide
#   "wavelength_y": periods[:, np.newaxis] / (aspect * np.sin(thetas[np.newaxis, :])),

# %%
# Denoising
noise_level = 0.03 #units of BI
wavy_stuff, denoised_cwt = two.denoise_2d(cwt_result,white_noise_level=4*noise_level,sMAD_threshold=None,mean_axis=(1,2,3))

# %%
data_lev = np.linspace(-0.4,0.4,31)
fig = plt.figure(figsize=(16,6))
ax1 = fig.add_subplot(311)
plot_orig = ax1.contourf(x,y,orig.T,levels=data_lev,extend='both',cmap='RdBu_r')
cbar = fig.colorbar(plot_orig)

ax2 = fig.add_subplot(312)
plot_dirt = ax2.contourf(x,y,BI_low.T+signal.T-wavy_stuff.T+np.mean(orig.values),levels=data_lev,extend='both',cmap='RdBu_r')
cbar = fig.colorbar(plot_dirt)

ax3 = fig.add_subplot(313)
plot_wave = ax3.contourf(x,y,wavy_stuff.T,levels=data_lev,extend='both',cmap='RdBu_r')
cbar = fig.colorbar(plot_wave)

ax3.set_xlabel('Along Distance / km')
ax1.set_ylabel('Across Distance / km')
ax2.set_ylabel('Across Distance / km')
ax3.set_ylabel('Across Distance / km')

letterbox = {"boxstyle": "circle","lw": 0.67,"facecolor": "white","edgecolor": "black"}
ax1.text(0.03,0.94,'a',transform=ax1.transAxes, bbox=letterbox, verticalalignment="top", horizontalalignment="right", weight="bold") 
ax2.text(0.03,0.94,'b',transform=ax2.transAxes, bbox=letterbox, verticalalignment="top", horizontalalignment="right", weight="bold") 
ax3.text(0.03,0.94,'c',transform=ax3.transAxes, bbox=letterbox, verticalalignment="top", horizontalalignment="right", weight="bold")
# Out:
# Text(0.03, 0.94, 'c')

# %%
WAS        = np.abs(denoised_cwt['decomposition'])
start_time = time.time()
seg_v1     = two.wavefield_segmentation_2d(WAS,0.1*noise_level,connectivity=1)
print("--- %s seconds ---" % (time.time() - start_time))
print('Identified', np.max(seg_v1), 'initial wave packets!')

k     = 2 * np.pi / cwt_result["period"]
theta = cwt_result["theta"]
eps   = np.abs(np.diff(np.log(k)))[0]*np.sqrt(2)
labels, cluster_labels = two.find_clusters_logk_theta(denoised_cwt, seg_v1, eps=eps)
cluster_map            = two.build_cluster_map_with_noise(labels,cluster_labels)
seg_v2                 = two.relabel_by_xy_overlap(seg_v1, cluster_map)
print('Number of wave packets after Clustering', np.max(seg_v2))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[16], line 3
#       1 WAS        = np.abs(denoised_cwt['decomposition'])
#       2 start_time = time.time()
# ----> 3 seg_v1     = two.wavefield_segmentation_2d(WAS,0.1*noise_level,connectivity=1)
#       4 print("--- %s seconds ---" % (time.time() - start_time))
#       5 print('Identified', np.max(seg_v1), 'initial wave packets!')
#
# File ~/WAVEGUISE/notebooks/../scripts/utils_2d_v3.py:332, in wavefield_segmentation_2d(data, peak_prominence, connectivity, periodic_axis, dtype)
#     329 if n_markers == 0:
#     330     return np.zeros(orig_shape, dtype=np.int32)
# --> 332 labels_pad = watershed(iwork_pad, markers=markers, connectivity=structure)
#     333 labels = merge_periodic_faces(labels_pad, orig_shape=orig_shape, periodic_axis=periodic_axis)
#     334 labels, _, _ = relabel_sequential(labels)
#
# File ~/.conda/envs/JuWavelet/lib/python3.12/site-packages/skimage/segmentation/_watershed.py:229, in watershed(image, markers, connectivity, offset, mask, compactness, watershed_line)
#     226 marker_locations = np.flatnonzero(output)
#     227 image_strides = np.array(image.strides, dtype=np.intp) // image.itemsize
# --> 229 _watershed_cy.watershed_raveled(
#     230     image.ravel(),
#     231     marker_locations,
#     232     flat_neighborhood,
#     233     mask,
#     234     image_strides,
#     235     compactness,
#     236     output.ravel(),
#     237     watershed_line,
#     238 )
#     240 output = crop(output, pad_width, copy=True)
#     242 return output
#
# KeyboardInterrupt:

# %%
seg_v3 = two.variance_filter(denoised_cwt, seg_v2, var_threshold=0.99)
print('Final number of wave packets:', np.max(seg_v3))

# %%
recon_WP, amp_WP, k_along_WP, k_across_WP = two.recon_allWP_2d(denoised_cwt, seg_v3)
lh_WP, th_WP = two.kxky_2_lhtheta(k_along_WP,k_across_WP)

# %%
data_lev = np.linspace(-0.4,0.4,31)
row, col = pt.define_figgrid(recon_WP.shape[0])
gskw = {"hspace": 0.05, "wspace": 0.05, "width_ratios": col*[1], "height_ratios": row*[1]}

fig, ax=plt.subplots(row,col, figsize=(36,12), gridspec_kw=gskw,sharex=True, sharey=True)

for i in range(row):
    for j in range(col):
        if i*col+j < recon_WP.shape[0]:
            #ax[i][j].contourf(the_new_shit[i*col+j,:,:],levels=rad_lev,extend="both",cmap="RdBu_r")
            masked = np.ma.masked_inside(recon_WP[i*col+j,:,:], -noise_level*0.1, noise_level*0.1)  
            norm = mcolors.TwoSlopeNorm(vmin=data_lev[0], vcenter=0.0, vmax=data_lev[-1])
            ax[i,j].contourf(x,y,masked.T,levels=data_lev,cmap="RdBu_r",norm=norm,extend='both')
            ax[i,j].text(0.5, 0.95, str(i*col+j+1), verticalalignment='center', horizontalalignment='center', transform=ax[i,j].transAxes, 
                                    weight='bold', bbox={"boxstyle" : "round", "lw":0.67, "facecolor":"white", "edgecolor":"black"})

# %%
WP1 = recon_WP[0]+recon_WP[4]+recon_WP[5]
WP2 = recon_WP[1]+recon_WP[2]

amp_WP1 = amp_WP[0]+amp_WP[4]+amp_WP[5]
amp_WP2 = amp_WP[1]+amp_WP[2]

# Falls xarray DataArrays: in numpy arrays umwandeln
lon_plot = lon.values
lat_plot = lat.values

central_lon = -175
central_lat = -78.0
#proj = ccrs.Stereographic(central_longitude=central_lon, central_latitude=central_lat)
proj = ccrs.NearsidePerspective(central_longitude=central_lon, central_latitude=central_lat, satellite_height=35785831, false_easting=0, false_northing=0, globe=None)
data_crs = ccrs.PlateCarree()

row, col = 2, 3

gskw = {"hspace": 0.05, "wspace": 0.05, "width_ratios": [10, 10, 1], "height_ratios": [1] * row}

fig, ax = plt.subplots(row, col, figsize=(12, 9), subplot_kw={"projection": proj}, gridspec_kw=gskw, squeeze=False)
ax[0,2].axis('off')
ax[1,2].axis('off')

amp_mask = amp_WP1 > noise_level/2 
plot_WP_0 = ax[0, 0].scatter(lon_plot[amp_mask], lat_plot[amp_mask], c=WP1[amp_mask], s=1, vmin=-0.2, vmax=0.2, cmap='RdBu_r', transform=data_crs)
plot_lh_0 = ax[1, 0].scatter(lon_plot[amp_mask], lat_plot[amp_mask], c=lh_WP[0][amp_mask]*1e-3, s=1, vmin=100, vmax=300, transform=data_crs)

amp_mask = amp_WP2 > noise_level/2 
plot_WP_1 = ax[0, 1].scatter(lon_plot[amp_mask], lat_plot[amp_mask], c=WP2[amp_mask], s=1, vmin=-0.2, vmax=0.2, cmap='RdBu_r', transform=data_crs)
plot_lh_1 = ax[1, 1].scatter(lon_plot[amp_mask], lat_plot[amp_mask], c=lh_WP[1][amp_mask]*1e-3, s=1, vmin=100, vmax=300, transform=data_crs)
plot_lh_1 = ax[1, 1].scatter(lon_plot[amp_mask], lat_plot[amp_mask], c=lh_WP[2][amp_mask]*1e-3, s=1, vmin=100, vmax=300, transform=data_crs)

ax[0,0].plot([-175,-175],[-20,-90],transform=data_crs, linewidth=2)

seconds = ds.time.isel(NTRACK=track_slice).mean().values
date = datetime(2000, 1, 1) + timedelta(seconds=int(seconds))

ax[0,0].set_title(date)

for i in range(2):
    for j in range(2):
        ax[i, j].coastlines(linewidth=0.5)
        gl = ax[i, j].gridlines(draw_labels=False, linewidth=0.4, color="gray", alpha=0.5, linestyle="--")

        ax[i, j].set_extent(
            [
                np.nanmin(lon_plot),
                np.nanmax(lon_plot),
                np.nanmin(lat_plot),
                np.nanmax(lat_plot),
            ],
            crs=data_crs
        )
        
fig.colorbar(plot_WP_0, ax=ax[0,2], orientation="vertical", label="Temperature perturbation / K")
fig.colorbar(plot_lh_0, ax=ax[1,2], orientation="vertical", label="Horizontal wavelength / km")

letterbox = {"boxstyle": "circle","lw": 0.67,"facecolor": "white","edgecolor": "black"}
ax[0,0].text(0.05,0.95,'a',transform=ax[0,0].transAxes, bbox=letterbox, verticalalignment="top", horizontalalignment="right", weight="bold") 
ax[0,1].text(0.05,0.95,'b',transform=ax[0,1].transAxes, bbox=letterbox, verticalalignment="top", horizontalalignment="right", weight="bold") 
ax[1,0].text(0.05,0.95,'c',transform=ax[1,0].transAxes, bbox=letterbox, verticalalignment="top", horizontalalignment="right", weight="bold") 
ax[1,1].text(0.05,0.95,'d',transform=ax[1,1].transAxes, bbox=letterbox, verticalalignment="top", horizontalalignment="right", weight="bold") 

plt.savefig('./figures/2D_example_AIRS_OP3.png',dpi=150,bbox_inches="tight",pad_inches=0.02)
